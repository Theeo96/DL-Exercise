# %%
import os, sys

# print(os.getcwd())
current_dir = os.path.dirname(os.getcwd())
print(current_dir)

os.chdir(current_dir)

import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from ch04.two_layer_net_backpropa import TwoLayerNet
# Out:
# c:\workspace\DL-Exercise\notebooks\DL3_20241006

# %%
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True, one_hot_label=True)

network = TwoLayerNet(input_size=784, hidden_size=250, output_size=10)

iters_num = 20000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.5

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)

for i in range(iters_num) :
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grad = network.gradient(x_batch, t_batch)
    # grad = network.numerical_gradient(x_batch, t_batch)

    for key in ('W1', 'b1', 'W2', 'b2') :
        network.params[key] -= learning_rate * grad[key]

    loss = network.loss(x_batch, t_batch)
    train_loss_list.append(loss)

    if i % iter_per_epoch == 0 :
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)
        print(i, "train acc, test acc | " + str(train_acc) + ", " + str(test_acc))

print('Done')
# Out:
# 0 train acc, test acc | 0.27076666666666666, 0.2684
# 600 train acc, test acc | 0.9494666666666667, 0.9494
# 1200 train acc, test acc | 0.9720333333333333, 0.967
# 1800 train acc, test acc | 0.981, 0.9729
# 2400 train acc, test acc | 0.98625, 0.9775
# 3000 train acc, test acc | 0.9886166666666667, 0.9775
# 3600 train acc, test acc | 0.9912, 0.9796
# 4200 train acc, test acc | 0.9921166666666666, 0.978
# 4800 train acc, test acc | 0.99435, 0.9796
# 5400 train acc, test acc | 0.99505, 0.9809
# 6000 train acc, test acc | 0.9961, 0.981
# 6600 train acc, test acc | 0.9972, 0.982
# 7200 train acc, test acc | 0.9974333333333333, 0.9815
# 7800 train acc, test acc | 0.99805, 0.9809
# 8400 train acc, test acc | 0.9987666666666667, 0.9822
# 9000 train acc, test acc | 0.9991333333333333, 0.9826
# 9600 train acc, test acc | 0.9992333333333333, 0.9827
# 10200 train acc, test acc | 0.9993833333333333, 0.9821
# 10800 train acc, test acc | 0.9996833333333334, 0.9828
# 11400 train acc, test acc | 0.9997333333333334, 0.9833
# 12000 train acc, test acc | 0.9998333333333334, 0.9823
# 12600 train acc, test acc | 0.9998833333333333, 0.9821
# 13200 train acc, test acc | 0.9999, 0.9822
# 13800 train acc, test acc | 0.99965, 0.983
# 14400 train acc, test acc | 0.9999333333333333, 0.9822
# 15000 train acc, test acc | 0.9999666666666667, 0.9824
# 15600 train acc, test acc | 0.9999833333333333, 0.9823
# 16200 train acc, test acc | 0.9999666666666667, 0.9821
# 16800 train acc, test acc | 0.9999833333333333, 0.9819
# 17400 train acc, test acc | 1.0, 0.9828
# 18000 train acc, test acc | 1.0, 0.9828
# 18600 train acc, test acc | 1.0, 0.983
# 19200 train acc, test acc | 1.0, 0.983
# 19800 train acc, test acc | 1.0, 0.9829
# Done
